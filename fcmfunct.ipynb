# %%
import random
import numpy as np
from numpy import linalg as LA

# import FuzzyCMeans as fcm
import FCMeans as fcm
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_blobs

# %%
# Dados para os problema
mu = 2 #fuzificador expoente peso
c = 4 #qntde de grupos
eps = 1e-10 #criterio de parada

# %%
n = 50
X, y = make_blobs(n_samples=n, centers=c, random_state=42, cluster_std=1)
# y = 2*y-1
plt.scatter(X[:, 0], X[:, 1], s=30, cmap='autumn')
itmax = 500

# %%
C1 = fcm.C_init(X,c)
for mu in [1+1e9*eps,1.25,1.5,1.75,2]:
    C,U,it = fcm.FCM(X,mu,c,eps,itmax,C1)
    print(it, 'iterações', 'm =', mu)
    plt.plot(X[:, 0], X[:, 1],'bo')
    plt.plot(C[:, 0], C[:, 1],'ro') 
    plt.plot(C1[:, 0], C1[:, 1],'yo') 
#     plt.scatter(X[:, 0], X[:, 1], s=30, cmap='autumn')
#     plt.scatter(C[:, 0], C[:, 1], s=60, cmap='autumn') 
#     plt.scatter(C1[:, 0], C1[:, 1], s=20, cmap='autumn') 
    plt.show()
# Out:
# 5 iterações m = 1.1
# 7 iterações m = 1.25
# 9 iterações m = 1.5
# 12 iterações m = 1.75
# 15 iterações m = 2
